# %%
import pandas as pd
from datetime import datetime

# Read the Excel file into a DataFrame
df = pd.read_excel('Data_GamesCompanies/Data_ALL.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   #                     1200 non-null   int64
#  1   Unified App           1200 non-null   object
#  2   Classification        1200 non-null   object
#  3   Downloads             1176 non-null   float64
#  4   Cumulative Downloads  1200 non-null   int64
#  5   Revenue               1200 non-null   int64
#  6   Cumulative Revenue    1200 non-null   int64
#  7   Revenue/Downloads     1200 non-null   object
#  8   Paid Downloads        1003 non-null   float64
#  9   Organic Downloads     1151 non-null   float64
#  10  % Paid Downloads      1200 non-null   float64
#  11  % Organic Downloads   1200 non-null   float64
#  12  Usage Penetration     1200 non-null   object
#  13  Active Users          1200 non-null   int64
#  14  Install Penetration   1200 non-null   float64
# ...

# %%
# Columns to convert to numeric
numeric_columns = ['Revenue/Downloads', 'Usage Penetration', 'Avg Sessions / User']

# Convert specified columns to numeric
for col in numeric_columns:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# Columns to convert from date to amount number
date_columns = ['Avg Session Duration', 'Avg Time / User']

for col in date_columns:
    df[col] = pd.to_datetime(df[col], format='%Y-%m-%d %H:%M:%S.%f', errors='coerce')
    df[col] = df[col].apply(lambda x: (x.hour * 60) + (x.minute) + (x.second / 60) if not pd.isnull(x) else None)

# Example time count conversion
time_count = '1900-01-02 00:04:10.992000'
time_obj = datetime.strptime(time_count, '%Y-%m-%d %H:%M:%S.%f')
total_minutes = time_obj.second // 60 + time_obj.minute + time_obj.hour * 60
print(total_minutes)

# Now you can work with the transformed DataFrame 'df'
df.head(3)
# Out:
# 4
#    #       Unified App    Classification  Downloads  Cumulative Downloads  \
# 0  1       Coin Master        Luck Batle    44000.0               6240000
# 1  2  Candy Crush Saga                M3    66700.0              29700000
# 2  3            ROBLOX  Creative Sandbox   242000.0              11100000
#
#    Revenue  Cumulative Revenue  Revenue/Downloads  Paid Downloads  \
# 0  2650000            86300000              13.83         24900.0
# 1  1180000            80700000               2.72         25600.0
# 2   718000            29100000               2.63         30800.0
#
#    Organic Downloads  ...  Avg Sessions / User  Avg Session Duration  \
# 0            19100.0  ...                81.57              4.166667
# 1            41100.0  ...                58.39              8.466667
# 2           212000.0  ...                81.40              9.950000
#
#    Avg Time / User    Total Time  Avg Active Days  % Active Days       Genre  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   #                     1200 non-null   int64
#  1   Unified App           1200 non-null   object
#  2   Classification        1200 non-null   object
#  3   Downloads             1176 non-null   float64
#  4   Cumulative Downloads  1200 non-null   int64
#  5   Revenue               1200 non-null   int64
#  6   Cumulative Revenue    1200 non-null   int64
#  7   Revenue/Downloads     1000 non-null   float64
#  8   Paid Downloads        1003 non-null   float64
#  9   Organic Downloads     1151 non-null   float64
#  10  % Paid Downloads      1200 non-null   float64
#  11  % Organic Downloads   1200 non-null   float64
#  12  Usage Penetration     1171 non-null   float64
#  13  Active Users          1200 non-null   int64
#  14  Install Penetration   1200 non-null   float64
# ...

# %%
df.to_excel('Data_GamesCompanies/Data_ALL.xlsx', index=False)

# %%
df.head(3)
# Out:
#    #       Unified App    Classification  Downloads  Cumulative Downloads  \
# 0  1       Coin Master        Luck Batle    44000.0               6240000
# 1  2  Candy Crush Saga                M3    66700.0              29700000
# 2  3            ROBLOX  Creative Sandbox   242000.0              11100000
#
#    Revenue  Cumulative Revenue  Revenue/Downloads  Paid Downloads  \
# 0  2650000            86300000              13.83         24900.0
# 1  1180000            80700000               2.72         25600.0
# 2   718000            29100000               2.63         30800.0
#
#    Organic Downloads  ...  Avg Sessions / User  Avg Session Duration  \
# 0            19100.0  ...                81.57              4.166667
# 1            41100.0  ...                58.39              8.466667
# 2           212000.0  ...                81.40              9.950000
#
#    Avg Time / User    Total Time  Avg Active Days  % Active Days       Genre  \
# ...
