# %%
import pandas as pd
import re

# %% [markdown]
# Data source : Data.ai - Mobile Games Statistics scrapped by converting in PDF and transforming the PDF to excel.

# %%
# # Initialize the temporary ID list
# temp_id_list = []

# # Iterate over each row
# for index, row in df.iterrows():
#     # Get the words in reverse order for the current row
#     words = row['Unified App'].split()[::-1]
    
#     # Find rows with matching words in reverse order
#     matching_rows = df[df['Unified App'].str.split()[::-1] == words]
    
#     # Extract the corresponding ID values
#     matching_ids = matching_rows['ID'].tolist()
    
#     # Add the IDs to the temporary ID list
#     temp_id_list.extend(matching_ids)
    
# # Remove duplicate IDs from the temporary list
# temp_id_list = list(set(temp_id_list))

# # Create the 'Publisher List'
# editor_list = df[df['ID'].isin(temp_id_list)]['Unified App'].tolist()

# # Create the 'Manual Publisher List'
# manual_editor_list = df[~df['ID'].isin(temp_id_list)]['Unified App'].tolist()

# # Print the results
# print("publisher List:")
# for app in publisher_list:
#     print(app)

# print("\nManual Publisher List:")
# for app in manual_publisher_list:
#     print(app)

# %%
# # Initialize temporary lists
# temp_apps = []
# publisher_list = []
# manual_publisher_list = []

# # Iterate over each row
# for index, row in df.iterrows():
#     words = row['Unified App'].split()[::-1]  # Get the words in reverse order for the current row
    
#     matching_apps = []
    
#     # Compare reverse words with all other rows
#     for inner_index, inner_row in df.iterrows():
#         inner_words = inner_row['Unified App'].split()[::-1]
        
#         if words == inner_words:
#             matching_apps.append(inner_row['Unified App'])
    
#     if matching_apps:
#         temp_apps.extend(matching_apps)
#         publisher_list.extend(matching_apps)
#     else:
#         manual_publisher_list.append(row['Unified App'])

# # Remove duplicate apps from the temporary list
# temp_apps = list(set(temp_apps))

# # Print the results
# print("Publisher List:")
# for app in publisher_list:
#     print(app)

# print("\nManual Publisher List:")
# for app in manual_publisher_list:
#     print(app)

# %%
# # Initialize temporary lists
# temp_apps = []
# editor_list = []
# manual_editor_list = []

# # Iterate over each row
# for index, row in df.iterrows():
#     words = row['Unified App'].split()[::-1]  # Get the words in reverse order for the current row
    
#     matching_apps = []
    
#     # Compare reverse words with all other rows
#     for inner_index, inner_row in df.iterrows():
#         inner_words = inner_row['Unified App'].split()[::-1]
        
#         if words == inner_words:
#             matching_apps.append(inner_words[0])  # Add only the first word to the matching apps
    
#     if matching_apps:
#         temp_apps.extend(matching_apps)
#         editor_list.extend(matching_apps)
#     else:
#         manual_editor_list.append(row['Unified App'])

# # Remove duplicate apps from the temporary list
# temp_apps = list(set(temp_apps))

# # Print the results
# print("Publisher List:")
# for app in publisher_list:
#     print(app)

# print("\nManual Editor List:")
# for app in manual_editor_list:
#     print(app)

# %%
# # Create empty lists
# last_word = []
# editor_list = []
# manual_editor_list = []

# # Iterate over each row of the DataFrame
# for idx, row in df.iterrows():
#     app_string = row['Unified App']  # Get the value of 'Unified App' for the current row

#     # Split the 'Unified App' string into individual words
#     app_words = app_string.split()

#     if app_words:
#         current_word = app_words[-1]  # Get the last word of the 'Unified App' string

#         if not last_word:
#             last_word.append(current_word)
#         else:
#             found_match = False

#             # Compare current_word with previous words in the last_word list
#             for index, word in reversed(list(enumerate(last_word))):
#                 if current_word == word:
#                     found_match = True
#                     pos = len(last_word) - index - 1
#                     combined_words = ' '.join(app_words[: len(app_words) - 1])  # Combine previous words of the 'Unified App' string
#                     last_word.append(combined_words)
#                     break

#             if found_match:
#                 # Perform deeper comparison on the 'Unified App' strings and check previous words
#                 deeper_comparison = app_string == df.iloc[idx - pos]['Unified App']

#                 if deeper_comparison:
#                     last_word.append(app_string)
#                 else:
#                     editor_list.append(app_string)
#             else:
#                 manual_editor_list.append(app_string)
#     else:
#         manual_editor_list.append(app_string)

# # Print the lists
# print("Last Word List:", last_word)
# print("Editor List:", editor_list)
# print("Manual Editor List:", manual_editor_list)

# %%
def extract_publisher(dataframe):
    # Initialize temporary lists
    temp_apps = []
    publisher_list = []
    manual_editor_list = []

    # Iterate over each row
    for index, row in dataframe.iterrows():
        words = row['Unified App'].split()[::-1]  # Get the words in reverse order for the current row
        
        matching_apps = []
        
        # Compare reverse words with all other rows
        for inner_index, inner_row in dataframe.iterrows():
            inner_words = inner_row['Unified App'].split()[::-1]
            
            if words == inner_words:
                matching_apps.append(inner_words[0])  # Add only the first word to the matching apps
        
        if matching_apps:
            temp_apps.extend(matching_apps)
            editor_list.extend(matching_apps)
        else:
            manual_editor_list.append(row['Unified App'])

    # Remove duplicate apps from the temporary list
    temp_apps = list(set(temp_apps))

    # Print the results
    print("Publisher List:")
    for app in publisher_list:
        print(app)

    print("\nManual Editor List:")
    for app in manual_editor_list:
        print(app)

# %%
def add_publisher_into_df(df):
    # Load the company list data into a DataFrame
    df_companies = pd.read_excel('XLS/Companies_List.xlsx')

    # Extract the 'Company' column into a set
    companies = set(df_companies['Company'])
    # Create the new 'Company' column
    df['Company'] = ''

    # Iterate through the companies
    for string in companies:
        # Find the index positions where the string matches at the end of 'Unified App'
        match_indices = df['Unified App'].str.endswith(string, na=False)
        # Update 'Company' column with matching strings from 'Unified App'
        df.loc[match_indices, 'Company'] = string
        # Remove the string from the end of 'Unified App'
        df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()

    return df

# %%
#Creating year and month columns

# %%
#List of DataSources
date_id = ["2307", "2306", "2305", "2304", "2303", "2302", "2301", "2212", "2211", "2210", "2209", "2208"]

for date in date_id:
    # 1 - Importing all Data from excel sheets
    data = pd.read_excel(f'XLS/Data_{date}.xlsx')

    # 2 - Removing all fully NaN Rows and Columns
    # Find rows containing only null values & Drop the null rows
    try:
        null_rows = data.rows[data.isnull().all()]
        df = data.drop(columns=null_columns)
    except:
        pass
    # Find columns containing only null values & Drop the null columns
    try:
        null_columns = data.columns[data.isnull().all()]
        df = data.drop(columns=null_columns)
    except:
        pass

    # 3 - Remove unwanted character and reasign corresponding value types
    # Specify the columns to clean
    columns_to_clean = ['Downloads', 'Cumulative Downloads', 'Revenue', 'Cumulative Revenue',
                        'Paid Downloads', 'Organic Downloads', 'Active Users', 'Install Base', 'Total Time']
    # Remove unwanted characters and convert numbers to their numerical equivalent
    for column in columns_to_clean:
        try:
            df[column] = df[column].str.replace(r'[\$]', '', regex=True)  # Remove '$' and '.'
        except:
            pass
        try:
            df[column] = df[column].str.replace(r'(\d+)([kK])', r'\g<1>e3', regex=True)  # Convert 'k' to '*1e3'
        except:
            pass
        try:
            df[column] = df[column].str.replace(r'(\d+)([mM])', r'\g<1>e6', regex=True)  # Convert 'm' to '*1e6'
        except:
            pass
        try:
            df[column] = df[column].str.replace(r'(\d+)([bB])', r'\g<1>e9', regex=True)  # Convert 'b' to '*1e9'
        except:
            pass
        try:
            df[column] = pd.to_numeric(df[column])  # Convert the column to numeric data type
        except:
            pass

    # 4 - Retrieving the Game's Genre in the 'Classification' Column and creating a column 'Genre'
    # Remove leading line break from 'Classification' and extract words after it into 'Genre'
    try:
        df['Genre'] = df['Classification'].str.split('\n').str[-1].str.strip()
        df['Classification'] = df['Classification'].str.replace('\n.*', '', regex=True)
    except:
        pass

    # 5 - Retrieving the Publisher of the Games and adding to a new column 'Publisher'
    #extract_publisher(df)
    add_publisher_into_df(df)

    # Save the resulting DataFrame to a new Excel file
    df.to_excel(f'clean_data_{date}.xlsx', index=False)
    df
# Out:
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()
# /var/folders/bl/h6hj0_vn0_z33qjysk6lj3qm0000gn/T/ipykernel_68900/1063223243.py:17: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Unified App'] = df['Unified App'].str.replace(f'{string}$', '', flags=re.IGNORECASE).str.strip()

# %%
data_view = pd.read_excel('clean_data_2208.xlsx')
data_view
# Out:
#       #                      Unified App          Classification  Downloads  \
# 0     1                      Coin Master              Luck Batle    48900.0
# 1     2                 Candy Crush Saga                      M3   119000.0
# 2     3                     Stumble Guys            Party Royale   667000.0
# 3     4                           ROBLOX        Creative Sandbox   194000.0
# 4     5               Gardenscapes - New                 M3-Meta    48800.0
# ..  ...                              ...                     ...        ...
# 95   96  Billionaire Casino Huuuge Games                   Slots     3300.0
# 96   97                      Rush Royale  Tower Defense Strategy    30400.0
# 97   98       Last Fortress: Underground          4X March-Batle    24800.0
# 98   99              Matchington Mansion                 M3-Meta    10400.0
# 99  100   World Series of Poker Playtika                   Poker     4700.0
#
#     Cumulative Downloads  Revenue  Cumulative Revenue  \
# 0                5500000  3500000            55900000
# 1               28600000  1240000            67800000
# 2                6360000  1120000             4150000
# 3                9240000   677000            21800000
# 4                7500000   520000            27600000
# ..                   ...      ...                 ...
# 95                504000    44900             2420000
# 96                789000    43800              793000
# 97                209000    43200              364000
# 98               2670000    42100             5210000
# 99               1540000    41100             2750000
#
#     RPD\nAs of Aug 31, 2022  Paid Downloads  Organic Downloads  ...  \
# 0                     10.16         24900.0            24000.0  ...
# 1                      2.37         34700.0            83900.0  ...
# 2                      0.65        169000.0           498000.0  ...
# 3                      2.36          4800.0           189000.0  ...
# 4                      3.68         24600.0            24200.0  ...
# ..                      ...             ...                ...  ...
# 95                     4.79          1400.0             1900.0  ...
# 96                     1.00         18100.0            12300.0  ...
# 97                     1.74          8200.0            16600.0  ...
# 98                     1.95          5800.0             4600.0  ...
# 99                     1.79          1400.0             3300.0  ...
#
#     Install Base  Open Rate Avg Sessions / User    Avg Session Duration  \
# 0        2960000     0.5172               73.45 1900-01-01 00:04:52.982
# 1        3980000     0.5819                62.1 1900-01-01 00:06:38.995
# 2        7310000     0.5572               28.09 1900-01-01 00:06:59.990
# 3        5810000     0.4815               68.39 1900-01-01 00:08:51.965
# 4        1120000     0.6090               47.87 1900-01-01 00:09:36.029
# ..           ...        ...                 ...                     ...
# 95         65900     0.1400               10.89 1900-01-01 00:11:29.040
# 96        273000     0.3041               17.15 1900-01-01 00:07:13.037
# 97        156000     0.4275                9.57 1900-01-01 00:38:28.003
# 98        288000     0.3781               60.49 1900-01-01 00:09:52.013
# 99        122000     0.2453              100.48 1900-01-01 00:03:46.022
#
#                Avg Time / User    Total Time  Avg Active Days % Active Days  \
# 0   1900-01-01 05:58:41.981000  6.110000e+08            11.77        0.3796
# 1   1900-01-01 06:52:31.958000  1.220000e+09             9.25        0.2985
# 2   1900-01-01 03:16:43.018000  1.050000e+09             7.66        0.2471
# 3   1900-01-01 10:05:59.021000  1.790000e+09             9.72        0.3137
# 4   1900-01-01 07:39:22.032000  4.060000e+08            10.42        0.3361
# ..                         ...           ...              ...           ...
# 95  1900-01-01 02:05:02.976000  1.240000e+06             3.45        0.1113
# 96  1900-01-01 02:03:51.005000  1.190000e+07             3.28        0.1056
# 97  1900-01-01 06:08:12.998000  2.830000e+07             3.94        0.1271
# 98  1900-01-01 09:56:57.034000  9.760000e+07             7.22        0.2329
# 99  1900-01-01 06:19:02.986000  1.250000e+07             5.17        0.1669
#
#          Genre            Company
# 0        Party        Moon Active
# 1        Match               King
# 2        Party            Scopely
# 3   Simulation             Roblox
# 4        Match      Acres Playrix
# ..         ...                ...
# 95      Casino                NaN
# 96    Strategy          UPWAKE.ME
# 97    Strategy  Long Tech Network
# 98       Match       Magic Tavern
# 99      Casino                NaN
#
# [100 rows x 25 columns]

# %%
# Check for null values in the 'Unified App' column
null_values = df['Unified App'].isnull().sum()

# Print the number of null values
print("Number of null values in 'Unified App' column:", null_values)
# Out:
# Number of null values in 'Unified App' column: 0

# %%
# Check for null values in the 'Unified App' column
null_values = df['Company'].isnull().sum()

# Print the number of null values
print("Number of null values in 'Company' column:", null_values)
# Out:
# Number of null values in 'Company' column: 0

# %% [markdown]
# ### Used to find all publisher missing from previous filtering

# %%
# List of DataSources
date_id = ["2307", "2306", "2305", "2304", "2303", "2302", "2301", "2212", "2211", "2210", "2209", "2208"]
missing_companies = set()  # Set to store missing companies

for date in date_id:
    global missing_companies

    # 1 - Importing all Cleaned Data from excel sheets
    df = pd.read_excel(f'clean_data_{date}.xlsx')

    # Load the company list data into a DataFrame
    df_companies = pd.read_excel('XLS/games_company.xlsx')

    # Extract the 'Company' column into a set
    companies = set(df_companies['Company'])

    for index, row in df.iterrows():
        unified_app = row['Unified App']
        company = row['Company']

        # Check if the 'Company' value is NaN (empty)
        if pd.isna(company):
            missing_companies.add(unified_app)

# Convert the set to a DataFrame
missing_companies_df = pd.DataFrame({'Missing Companies': list(missing_companies)})

# Save the DataFrame to an Excel file
missing_companies_df.to_excel('missing_companies.xlsx', index=False)

print("Missing companies :", missing_companies)
# Out:
# Missing companies : {'World Series of Poker Playtika', 'Captain Tsubasa: Dream Team KLab', 'Survivor!.io Habby', 'Tower of Fantasy Perfect World', 'Gossip Harbor MicroFun', 'Saint Seiya : Legend Of Justice Wanda Film', 'Mighty Party Panoramik Games', 'Fate/Grand Order Aniplex', 'Magic: The Gathering Arena Wizards of the Coast', 'Billionaire Casino Huuuge Games', 'Chess.com\nChess.com', 'Cash Tornado Slots Zeroo Gravity', 'Design Home Crowdstar', 'Mafia City\nYota Games', 'Summoners War Com2uS', 'The Grand Mafia Yota Games', 'Art of War: Legions 89Trillion', 'Dragon Hunters：Heroes Legend 4399', 'Pokémon Masters DeNA', 'Slotomania Playtika', 'Bloodline: Heroes of Lithas GOAT Games', 'POP! Slots\nPlayStudios', 'Online Soccer Manager OSM Gamebasics'}

# %%
# Read 'missing_companies.xlsx'
missing_companies_df = pd.read_excel('XLS/missing_companies.xlsx')
# Retrieve the 'Missing Companies' column and store it in 'updated_companies' set
updated_companies = set(missing_companies_df['Company'])

# Read 'games_companies.xlsx'
games_companies_df = pd.read_excel('XLS/games_company.xlsx')
# Retrieve the 'Company' column and update the 'updated_companies' set
updated_companies.update(set(games_companies_df['Company']))

# Create a DataFrame from the 'updated_companies' set
company_list_df = pd.DataFrame({'Company': list(updated_companies)})

# Save the DataFrame to 'Company_list.xlsx'
company_list_df.to_excel('Company_list.xlsx', index=False)

updated_companies
# Out:
# {'37 Entertainment',
#  '89Trillion',
#  'Acres Playrix',
#  'Activision Publishing',
#  'Aniplex',
#  'Artrix',
#  'BANDAI NAMCO Entertainment',
#  'Blizzard Entertainment',
#  'Boombox Games',
#  'Camel Games',
#  'Candivore',
#  'Century Games',
#  'Com2uS',
#  'Crowdstar',
#  'DeNA',
#  'Dream Games',
#  'Electronic Arts',
#  'Elex Technology',
#  'FunPlus',
#  'GOAT Games',
#  'Gamebasics',
#  'Gameberry',
#  'Garena Online',
#  'Green Horse Games',
#  'Habby',
#  'Hutch',
#  'Huuuge Games',
#  'Huuuge Huuuge Games',
#  'IGG',
#  'KLab',
#  'Kabam',
#  'KamaGames',
#  'Kefir',
#  'King',
#  'Lilith',
#  'Long Tech Network',
#  'Magic Tavern',
#  'Magmatic Games',
#  'Melsoft',
#  'Metacore Games',
#  'MicroFun',
#  'Miniclip',
#  'Mojang',
#  'Moon Active',
#  'Moonton',
#  'NetEase',
#  'Netmarble',
#  'Nexters',
#  'Niantic',
#  'Nordeus',
#  'Nuverse',
#  'Panoramik Games',
#  'Peak',
#  'Perfect World',
#  'Pipa',
#  'Plarium',
#  'PlayJoy Games',
#  'PlaySpace',
#  'PlayStudios',
#  'Playrix',
#  'Playtika',
#  'Playtika Santa Monica',
#  'Riot Games',
#  'Roblox',
#  'Scopely',
#  'Scorewarrior',
#  'Social Games Online',
#  'SpinX Games',
#  'StarUnion',
#  'Supercell',
#  'Superplay',
#  'Supertreat',
#  'TTHmobi',
#  'Tangelo',
#  'Ten Square Games',
#  'Tencent',
#  'Toca Boca',
#  'Top Games',
#  'Topwar Studio',
#  'UPWAKE.ME',
#  'Vizor',
#  'Wanda Film',
#  'Wildlife Studios',
#  'Wizards of the Coast',
#  'Wooga',
#  'Yalla',
#  'Yota Games',
#  'Yotta Games',
#  'Youda Games',
#  'Zeroo Gravity',
#  'Zynga',
#  'chess.com',
#  'miHoYo'}
