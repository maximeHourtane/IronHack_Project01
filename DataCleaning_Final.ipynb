# %% [markdown]
# # Initialisation + main VARIABLE

# %%
import pandas as pd

# Create your DataFrames (replace these with your actual DataFrames)
date_id = ["2307", "2306", "2305", "2304", "2303", "2302", "2301", "2212", "2211", "2210", "2209", "2208"]

# %% [markdown]
# # Verifying shapes of Datasets

# %%
for date in date_id:
    df = pd.read_excel(f'Data_GamesCompanies/Data_{date}.xlsx')
    print(df.shape)
# Out:
# (100, 27)
# (100, 27)
# (100, 27)
# (100, 27)
# (100, 27)
# (100, 27)
# (100, 27)
# (100, 27)
# (100, 27)
# (100, 27)
# (100, 27)
# (100, 27)

# %% [markdown]
# # Armonisation of column names

# %%
# Defining Exact Names for each columns
for date in date_id:
    df = pd.read_excel(f'Data_GamesCompanies/Data_{date}.xlsx')
    columns_names = [
        '#', 'Unified App', 'Classification', 'Downloads', 
        'Cumulative Downloads', 'Revenue', 'Cumulative Revenue', 
        'Revenue/Downloads', 'Paid Downloads', 'Organic Downloads', 
        '% Paid Downloads', '% Organic Downloads', 'Usage Penetration', 
        'Active Users', 'Install Penetration', 'Install Base', 
        'Open Rate', 'Avg Sessions / User', 'Avg Session Duration', 
        'Avg Time / User', 'Total Time', 
        'Avg Active Days', '% Active Days', 'Genre', 
        'Company', 'Year', 'Month'
    ]
    df.columns = columns_names

    # Save the resulting DataFrame to a new Excel file
    df.to_excel(f'Data_{date}.xlsx', index=False)

df.head(3)
# Out:
#    #       Unified App Classification  Downloads  Cumulative Downloads  \
# 0  1       Coin Master     Luck Batle    48900.0               5500000
# 1  2  Candy Crush Saga             M3   119000.0              28600000
# 2  3      Stumble Guys   Party Royale   667000.0               6360000
#
#    Revenue  Cumulative Revenue  Revenue/Downloads  Paid Downloads  \
# 0  3500000            55900000              10.16         24900.0
# 1  1240000            67800000               2.37         34700.0
# 2  1120000             4150000               0.65        169000.0
#
#    Organic Downloads  ...  Avg Sessions / User    Avg Session Duration  \
# 0            24000.0  ...                73.45 1900-01-01 00:04:52.982
# 1            83900.0  ...                 62.1 1900-01-01 00:06:38.995
# 2           498000.0  ...                28.09 1900-01-01 00:06:59.990
#
#               Avg Time / User    Total Time  Avg Active Days  % Active Days  \
# ...

# %% [markdown]
# # Removing unwanted characters

# %%
for date in date_id:
    df = pd.read_excel(f'Data_{date}.xlsx')

    # Specify the columns to clean
    columns_to_clean = ['Downloads', 'Cumulative Downloads', 'Revenue', 'Cumulative Revenue', 'Revenue/Downloads'
                        'Paid Downloads', 'Organic Downloads', 'Active Users', 'Install Base', 'Total Time']
    # Remove unwanted characters and convert numbers to their numerical equivalent
    for column in columns_to_clean:
        try:
            df['Revenue/Downloads'] = df['Revenue/Downloads'].str.replace(r'[\,]', '.', regex=True)  # Remove ',' with '.'
        except:
            pass
        try:
            df[column] = df[column].str.replace(r'[\$]', '', regex=True)  # Remove '$'
        except:
            pass
        try:
            df[column] = df[column].str.replace(r'(\d+)([kK])', r'\g<1>e3', regex=True)  # Convert 'k' to '*1e3'
        except:
            pass
        try:
            df[column] = df[column].str.replace(r'(\d+)([mM])', r'\g<1>e6', regex=True)  # Convert 'm' to '*1e6'
        except:
            pass
        try:
            df[column] = df[column].str.replace(r'(\d+)([bB])', r'\g<1>e9', regex=True)  # Convert 'b' to '*1e9'
        except:
            pass
        try:
            df[column] = pd.to_numeric(df[column])  # Convert the column to numeric data type
        except:
            pass

    # Save the resulting DataFrame to a new Excel file
    df.to_excel(f'Data_{date}.xlsx', index=False)

df.head(3)
# Out:
#    #       Unified App Classification  Downloads  Cumulative Downloads  \
# 0  1       Coin Master     Luck Batle    48900.0               5500000
# 1  2  Candy Crush Saga             M3   119000.0              28600000
# 2  3      Stumble Guys   Party Royale   667000.0               6360000
#
#    Revenue  Cumulative Revenue  Revenue/Downloads  Paid Downloads  \
# 0  3500000            55900000              10.16         24900.0
# 1  1240000            67800000               2.37         34700.0
# 2  1120000             4150000               0.65        169000.0
#
#    Organic Downloads  ...  Avg Sessions / User    Avg Session Duration  \
# 0            24000.0  ...                73.45 1900-01-01 00:04:52.982
# 1            83900.0  ...                 62.1 1900-01-01 00:06:38.995
# 2           498000.0  ...                28.09 1900-01-01 00:06:59.990
#
#               Avg Time / User    Total Time  Avg Active Days  % Active Days  \
# ...

# %% [markdown]
# # Datetime to amount in minuts

# %%
from datetime import datetime

# Columns to convert from date to amount number
date_columns = ['Avg Session Duration', 'Avg Time / User']

for date in date_id:
    df = pd.read_excel(f'Data_{date}.xlsx')

    for col in date_columns:
        df[col] = pd.to_datetime(df[col], format='%Y-%m-%d %H:%M:%S.%f', errors='coerce')
        df[col] = df[col].apply(lambda x: (x.hour * 60) + (x.minute) + (x.second / 60) if not pd.isnull(x) else None)

    # Save the resulting DataFrame to a new Excel file
    df.to_excel(f'Data_{date}.xlsx', index=False)

df.head(3)
# Out:
#    #       Unified App Classification  Downloads  Cumulative Downloads  \
# 0  1       Coin Master     Luck Batle    48900.0               5500000
# 1  2  Candy Crush Saga             M3   119000.0              28600000
# 2  3      Stumble Guys   Party Royale   667000.0               6360000
#
#    Revenue  Cumulative Revenue  Revenue/Downloads  Paid Downloads  \
# 0  3500000            55900000              10.16         24900.0
# 1  1240000            67800000               2.37         34700.0
# 2  1120000             4150000               0.65        169000.0
#
#    Organic Downloads  ...  Avg Sessions / User  Avg Session Duration  \
# 0            24000.0  ...                73.45              4.866667
# 1            83900.0  ...                 62.1              6.633333
# 2           498000.0  ...                28.09              6.983333
#
#   Avg Time / User    Total Time  Avg Active Days  % Active Days  Genre  \
# ...

# %% [markdown]
# # Check Types and Convert to Numeric

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   #                     100 non-null    int64
#  1   Unified App           100 non-null    object
#  2   Classification        100 non-null    object
#  3   Downloads             99 non-null     float64
#  4   Cumulative Downloads  100 non-null    int64
#  5   Revenue               100 non-null    int64
#  6   Cumulative Revenue    100 non-null    int64
#  7   Revenue/Downloads     100 non-null    float64
#  8   Paid Downloads        84 non-null     float64
#  9   Organic Downloads     96 non-null     float64
#  10  % Paid Downloads      100 non-null    float64
#  11  % Organic Downloads   100 non-null    float64
#  12  Usage Penetration     100 non-null    object
#  13  Active Users          100 non-null    int64
#  14  Install Penetration   100 non-null    float64
# ...

# %%
# Columns to convert to numeric
numeric_columns = ['Revenue/Downloads', 'Usage Penetration', 'Avg Sessions / User']

for date in date_id:
    df = pd.read_excel(f'Data_{date}.xlsx')

    # Convert specified columns to numeric
    for col in numeric_columns:
        df[col] = pd.to_numeric(df[col], errors='coerce')
    
    # Save the resulting DataFrame to a new Excel file
    df.to_excel(f'Data_{date}.xlsx', index=False)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   #                     100 non-null    int64
#  1   Unified App           100 non-null    object
#  2   Classification        100 non-null    object
#  3   Downloads             99 non-null     float64
#  4   Cumulative Downloads  100 non-null    int64
#  5   Revenue               100 non-null    int64
#  6   Cumulative Revenue    100 non-null    int64
#  7   Revenue/Downloads     100 non-null    float64
#  8   Paid Downloads        84 non-null     float64
#  9   Organic Downloads     96 non-null     float64
#  10  % Paid Downloads      100 non-null    float64
#  11  % Organic Downloads   100 non-null    float64
#  12  Usage Penetration     99 non-null     float64
#  13  Active Users          100 non-null    int64
#  14  Install Penetration   100 non-null    float64
# ...

# %% [markdown]
# # Check Issues HERE by calling the dataset you want to verify

# %%
df_view = pd.read_excel('Data_2209.xlsx')
df.head(3)
# Out:
#    #       Unified App Classification  Downloads  Cumulative Downloads  \
# 0  1       Coin Master     Luck Batle    48900.0               5500000
# 1  2  Candy Crush Saga             M3   119000.0              28600000
# 2  3      Stumble Guys   Party Royale   667000.0               6360000
#
#    Revenue  Cumulative Revenue  Revenue/Downloads  Paid Downloads  \
# 0  3500000            55900000              10.16         24900.0
# 1  1240000            67800000               2.37         34700.0
# 2  1120000             4150000               0.65        169000.0
#
#    Organic Downloads  ...  Avg Sessions / User  Avg Session Duration  \
# 0            24000.0  ...                73.45              4.866667
# 1            83900.0  ...                62.10              6.633333
# 2           498000.0  ...                28.09              6.983333
#
#    Avg Time / User    Total Time  Avg Active Days  % Active Days  Genre  \
# ...

# %%
df_view.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   #                     100 non-null    int64
#  1   Unified App           100 non-null    object
#  2   Classification        100 non-null    object
#  3   Downloads             99 non-null     float64
#  4   Cumulative Downloads  100 non-null    int64
#  5   Revenue               100 non-null    int64
#  6   Cumulative Revenue    100 non-null    int64
#  7   Revenue/Downloads     100 non-null    float64
#  8   Paid Downloads        84 non-null     float64
#  9   Organic Downloads     96 non-null     float64
#  10  % Paid Downloads      100 non-null    float64
#  11  % Organic Downloads   100 non-null    float64
#  12  Usage Penetration     97 non-null     float64
#  13  Active Users          100 non-null    int64
#  14  Install Penetration   100 non-null    float64
# ...
